# %% [markdown]
# <a href="https://colab.research.google.com/github/vatsaryan07/EPL-20-21-ft-COVID-19/blob/main/EPL_20_21_ft_Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import pi
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pd.set_option('mode.chained_assignment', None)

# %%
sns.set_theme(context='poster',font = 'arial')
sns.set_style('ticks')

# %%
#! pip install datapane
#import datapane as dp

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3ac3f84e-837e-4775-870b-29c89c705732" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ac3f84e-837e-4775-870b-29c89c705732">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 18-19 Away MW19.csv to 18-19 Away MW19 (1).csv
# Saving 18-19 Home MW19.csv to 18-19 Home MW19 (1).csv
# Saving 18-19 MW19.csv to 18-19 MW19 (1).csv
# Saving 19-20 Away MW19.csv to 19-20 Away MW19 (1).csv
# Saving 19-20 Goalkeeping.csv to 19-20 Goalkeeping (1).csv
# Saving 19-20 Home MW19.csv to 19-20 Home MW19 (1).csv
# Saving 19-20 MW17.csv to 19-20 MW17 (1).csv
# Saving 19-20 Passing.csv to 19-20 Passing (1).csv
# Saving 19-20 Shooting.csv to 19-20 Shooting (1).csv
# Saving 19-20 Shot Creation.csv to 19-20 Shot Creation (1).csv
# ...

# %%
! pip install chart_studio
import chart_studio
import chart_studio.plotly as py
ploto = open('plotly.txt','r')
plotop = ploto.read()
username = 'vatsaryan07'
api_key = plotop
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
st_1920 = pd.read_csv('19-20 Standard Stats.csv')
st_2021 = pd.read_csv('20-21 Standard Stats.csv')
st_2021['Squad'][11] = 'Man City'
st_1920['Squad'][11] = 'Man City'
st_2021['Squad'][12] = 'Man Utd'
st_1920['Squad'][12] = 'Man Utd'
st_1920
# Out:
#              Squad  # Pl   Age  Poss  MP  ...  xG.1  xA.1  xG+xA  npxG.1  npxG+xA
# 0          Arsenal    29  25.8  54.0  38  ...  1.30  0.79   2.08    1.24     2.02
# 1      Aston Villa    28  25.7  43.9  38  ...  1.05  0.80   1.85    0.99     1.79
# 2         Brighton    25  26.4  52.2  38  ...  1.08  0.70   1.78    1.04     1.74
# 3          Burnley    22  28.0  41.4  38  ...  1.15  0.72   1.87    1.09     1.81
# 4          Chelsea    27  25.5  60.7  38  ...  1.75  1.22   2.97    1.62     2.84
# 5   Crystal Palace    25  29.4  44.5  38  ...  0.90  0.62   1.52    0.84     1.46
# 6          Everton    24  25.5  49.2  38  ...  1.30  0.81   2.11    1.28     2.09
# 7           Fulham    28  26.9  61.5  46  ...   NaN   NaN    NaN     NaN      NaN
# 8     Leeds United    28  26.6  64.3  46  ...   NaN   NaN    NaN     NaN      NaN
# 9   Leicester City    24  26.2  57.6  38  ...  1.62  1.16   2.78    1.48     2.64
# ...

# %%
home_1819 = pd.read_csv('18-19 Home MW19.csv')
h1819_win = round(np.sum(home_1819['Won'])/np.sum(home_1819['Played'])*100,2)
away_1819 = pd.read_csv('18-19 Away MW19.csv')
a1819_win = round(np.sum(away_1819['Won'])/np.sum(away_1819['Played'])*100,2)
#print('Home Win Percentage 18/19 :',h1819_win)
#print('Away Win Percentage 18/19 :',a1819_win)

home_1920 = pd.read_csv('19-20 Home MW19.csv')
h1920_win = round(np.sum(home_1920['Won'])/np.sum(home_1920['Played'])*100,2)
away_1920 = pd.read_csv('19-20 Away MW19.csv')
a1920_win = round(np.sum(away_1920['Won'])/np.sum(away_1920['Played'])*100,2)
#print('Home Win Percentage 19/20 :',h1920_win)
#print('Away Win Percentage 19/20 :',a1920_win)
#avg_pt_1920 = (np.sum(home_1920['Points']) + np.sum(away_1920['Points']))/20
##print(avg_pt_1920)

home_2021 = pd.read_csv('20-21 Home MW19.csv')
h2021_win = round(np.sum(home_2021['Won'])/np.sum(home_2021['Played'])*100,2)
away_2021 = pd.read_csv('20-21 Away MW19.csv')
a2021_win = round(np.sum(away_2021['Won'])/np.sum(away_2021['Played'])*100,2)
#print('Home Win Percentage 20/21 :',h2021_win)
#print('Away Win Percentage 20/21 :',a2021_win)
#avg_pt_2021 = (np.sum(home_2021['Points']) + np.sum(away_2021['Points']))/20
##print(avg_pt_2021)

pd.set_option('mode.chained_assignment', None)
pt_2021 = pd.read_csv('20-21 MW17.csv')
ptdiff_2021 = pt_2021.loc[0]['Pts'] - pt_2021.loc[1]['Pts']
#print('Pts difference 20/21 :',ptdiff_2021)
avg_pt_2021 = np.mean(pt_2021.loc[0]['Pts'])
#print('Average Points 20/21 :',avg_pt_2021)
pt_2021 = pt_2021.sort_values('Squad')
pt_2021 = pt_2021.reset_index(drop = True)
pt_2021 = pt_2021[['Rk','Squad','MP','W','D','L','GDiff','Pts','GF','GA']]
pt_2021 = pt_2021.rename({"Rk":"Pos","GDiff":"GD"},axis = 'columns')
pt_2021 = pt_2021.drop([7,8,17])

pt_2021 = pt_2021.reset_index(drop = True)

pt_2021['Squad'][9] = 'Man City'
pt_2021['Squad'][10] = 'Man Utd'
pt_2021['Squad'][11] = 'Newcastle'
pt_2021['Squad'][7] = 'Leicester'
pt_2021


pt_1920 = pd.read_csv('19-20 MW17.csv')
ptdiff_1920 = pt_1920.loc[0]['Pts'] - pt_1920.loc[1]['Pts']
avg_pt_1920 = np.mean(pt_1920.loc[0]['Pts'])
#print(avg_pt_1920)
#print('Pts difference 19/20 :',ptdiff_1920)
pt_1920 = pt_1920.sort_values('Squad')
pt_1920 = pt_1920.drop([15,19,18])
pt_1920 = pt_1920.reset_index(drop=True)
pt_1920[['GF','GA']] = pt_1920['For:Against'].str.split(':',expand=True)
pt_1920 = pt_1920.drop(['For:Against'],axis = 1)

pt_1819 = pd.read_csv('18-19 MW19.csv')
ptdiff_1819 = pt_1819.loc[0]['Points'] - pt_1819.loc[1]['Points']
avg_pt_1819 = np.mean(pt_1819.loc[0]['Points'])
home_win = pd.Series([h1819_win,h1920_win,h2021_win])
away_win = pd.Series([a1819_win,a1920_win,a2021_win])
average_points = pd.Series([avg_pt_1819,avg_pt_1920,avg_pt_2021])
pts_diff = pd.Series([ptdiff_1819,ptdiff_1920,ptdiff_2021])
table = pd.DataFrame([home_win,away_win,average_points,pts_diff])
dum = ['18/19','19/20','20/21']
#print(avg_pt_1819)
#print('Pts difference 18/19 :',ptdiff_1819)
table
# Out:
#        0      1      2
# 0  45.26  43.39  38.38
# 1  34.74  32.28  38.38
# 2  51.00  55.00  40.00
# 3   6.00  16.00   2.00

# %%
# Plot of the comparisions between 18/19, 19/20 and 20/21 seasons on Home and Away Win Percentages, League Leaders' points and difference b/w the top two
fig = make_subplots(rows = 2,cols = 2,subplot_titles=('Home Win Percentage','Away Win Percentage','League Leaders','Difference between points of the top two'))

colours = ['indianred','darkcyan','darkmagenta']
fig.add_trace(go.Bar(
    name = 'Home Win Percentage',
    x = dum,
    y = home_win,
    text = home_win,
    textposition='auto',
    marker_color = colours,
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35),
row = 1,col = 1)

fig.add_trace(go.Bar(
    name = 'Away Win Percentage',
    x = dum,
    y = away_win,
    text = away_win,
    textposition='auto',
    marker_color = colours,
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35),
row = 1,col = 2)

fig.add_trace(go.Bar(
    name = 'Average Points of the top 10',
    x = dum,
    y = average_points,
    text = average_points,
    textposition='auto',
    marker_color = colours,
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35),
row = 2,col = 1)

fig.add_trace(go.Bar(
    name = 'Points difference between 1st and 2nd',
    x = dum,
    y = pts_diff,
    text = pts_diff,
    textposition='auto',
    marker_color = colours,
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35),
row = 2,col = 2)

fig.update_layout(title='Comparisions of 18/19, 19/20 and 20/21 seasons in terms of : ',
                  title_font_size = 20,
    xaxis_tickfont_size=18,
    #xaxis_tickangle = 30,
    yaxis=dict(
        title='Win Percentage',
        titlefont_size=14,
        tickfont_size=14,
        range = [0,47]
    ),
    xaxis2_tickfont_size=14,
    #xaxis1_tickangle = 30,
    yaxis2=dict(
        title='Win Percentage',
        titlefont_size=14,
        tickfont_size=14,
        range = [0,40]
    ),
    xaxis3_tickfont_size=14,
    #xaxis2_tickangle = 30,
    yaxis3=dict(
        title='Points',
        titlefont_size=14,
        tickfont_size=14,
        range = [0,56]
    ),
    xaxis4_tickfont_size=14,
    #xaxis3_tickangle = 30,
    yaxis4=dict(
        title='Points difference',
        titlefont_size=14,
        tickfont_size=14,
        range = [0,20]
    ),showlegend = False,
    height = 1000,# 
    #uniformtext_minsize = 10,
    #)#paper_bgcolor="LightSteelBlue")
)
for i in fig['layout']['annotations']:
    i['font']['size'] = 17
fig.show()
py.plot(fig, filename = 'plot_1', auto_open=True)
#report = dp.Report(dp.Plot(fig))
#report.publish(name = 'plot_1',open = True,visibility = 'PUBLIC')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="30f0dafc-83f3-438e-b4d4-f0307278c063" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("30f0dafc-83f3-438e-b4d4-f0307278c063")) {
#                     Plotly.newPlot(
#                         '30f0dafc-83f3-438e-b4d4-f0307278c063',
# ...

# %%
# Plot of goals scored / 90 of 19/20 vs 20/21
fig = go.Figure()

fig.add_trace(go.Bar(
    name = '19/20',
    x = st_1920['Squad'],
    y = st_1920['Gls.1'],
    text = st_1920['Gls.1'],
    textposition='outside',
    marker_color = 'rgb(55, 83, 109)',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.add_trace(go.Bar(name = '20/21',x = st_1920['Squad'],y = st_2021['Gls.1'],text = st_2021['Gls.1'],textposition='outside',marker_color = 'rgb(26, 118, 255)',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.update_layout(
    title='Goals scored per 90 by all clubs grouped by season',
    title_font_size = 30,
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Gls/90',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.3, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1,# 
    #uniformtext_minsize = 10, # gap between bars of the same location coordinate.
    #width = 2000,
    #height = 800,
    )#paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
fig.show()

py.plot(fig, filename = 'plot_2', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3c8ce375-bf2e-4f3c-86b0-746aa49cb15e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3c8ce375-bf2e-4f3c-86b0-746aa49cb15e")) {
#                     Plotly.newPlot(
#                         '3c8ce375-bf2e-4f3c-86b0-746aa49cb15e',
# ...

# %%
# Horizontal Bar Chart of the difference b/w Goals/90 of both seasons 

diff_g = pd.DataFrame()
diff_g['Squads'] = np.array(st_2021['Squad'])
diff_g['Difference'] = np.array(st_2021['Gls.1'] - st_1920['Gls.1'])
diff_g['Positive'] = diff_g['Difference']>0
fig = go.Figure()

fig.add_trace(go.Bar(
    name = '19/20',
    x = diff_g['Difference'],
    y = diff_g['Squads'],
    text = [round(i,2) for i in diff_g['Difference']],
    textposition='outside',
    marker_color = diff_g.Positive.map({True:'limegreen',False:'tomato'}),
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    #width = 0.35,
    orientation = 'h'))
fig.update_layout(
    title='Difference between Goals/90 of both seasons',
    title_font_size = 30,
    yaxis_tickfont_size=16,
    xaxis=dict(
        title='Diff Goals/90',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=1.0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
py.plot(fig,filename = 'plot_3',autoopen = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7077f142-2e40-47a8-a85a-55add3421903" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7077f142-2e40-47a8-a85a-55add3421903")) {
#                     Plotly.newPlot(
#                         '7077f142-2e40-47a8-a85a-55add3421903',
# ...

# %%
"""
As we see, the Goals/90 difference is a damning statistic that reveals the biggest underperformers and overperformers compared to last season in terms of goalscoring. 

Aston Villa have clearly benefitted with the addition of target man Ollie Watkins who while hasn't grabbed a lot of goals has surely allowed others from 
his team to get them. Although their statistic might be overcompensated based on THAT match against Liverpool, they have surely come good in the 20/21 season,
reflected by their place in the table. 

Everton, Crystal Palace and Leeds United are some other teams who have stepped up to the task and grabbed the season by the horns. While West Brom and 
Fulham have suffered with a goal shortage as was obviously going to be the case coming from the Championship up to the Premier League, Leeds once 
again defy logic in their incredibly high goals/90 difference, that too compared against a season in which they stormed to the Championship title. 

Manchester City still have a respectable goals/90 tally so far this season, but it is far from the lofty goalscoring standards they have set in the 
Premier League for the past two seasons. A damning -0.91 goals scored per 90 from last season puts them lower down than second bottom West Brom, who have managed to not 
be dead last in this table as well as the real one. While their goalscoring / 90 is still one of the best, they've fallen far from their 2.61 goals per 90 of last season. 
Arsenal, Burnley and Sheffield United have also suffered in the new conditions, and are 11th, 15th and 20th respectively, 
despite Arsenal looking to have turned a new corner under Mikel Arteta. 
"""
# Out:
# "\nAs we see, the Goals/90 difference is a damning statistic that reveals the biggest underperformers and overperformers compared to last season in terms of goalscoring. \n\nAston Villa have clearly benefitted with the addition of target man Ollie Watkins who while hasn't grabbed a lot of goals has surely allowed others from \nhis team to get them. Although their statistic might be overcompensated based on THAT match against Liverpool, they have surely come good in the 20/21 season,\nreflected by their place in the table. \n\nEverton, Crystal Palace and Leeds United are some other teams who have stepped up to the task and grabbed the season by the horns. While West Brom and \nFulham have suffered with a goal shortage as was obviously going to be the case coming from the Championship up to the Premier League, Leeds once \nagain defy logic in their incredibly high goals/90 difference, that too compared against a season in which they stormed to the Championship title. \n\nManchester Cit
# ...

# %%
gk_1920 = pd.read_csv('19-20 Goalkeeping.csv')
gk_2021 = pd.read_csv('20-21 Goalkeeping.csv')

# %%
#gk_1920

# %%
# Dropping the relegated teams to accomodate the promoted ones 

gk_1920 = gk_1920.drop([2,13,17])

# %%
gk_1920 = gk_1920.set_index('Squad')
gk_1920 = gk_1920.sort_index()
gk_1920 = gk_1920.reset_index()
gk_2021['Squad'][11] = 'Man City'
gk_1920['Squad'][11] = 'Man City'
gk_2021['Squad'][12] = 'Man Utd'
gk_1920['Squad'][12] = 'Man Utd'

# %%
"""fig,ax = plt.subplots()
fig.set_figheight(50)
fig.set_figwidth(100)
width = 0.35
b4 = ax.bar([i - 0.5*width for i in x],gk_1920['GA90'],width,label = '19/20',color = 'yellow')
b5 = ax.bar([i + 0.5*width for i in x],gk_2021['GA90'],width,label = '20/21',color = 'red',alpha = 0.5)
ax.set_ylabel('Goals conceded/90',fontsize = 50,color = 'black')
ax.set_title('Goals conceded/90 for all teams grouped by season',fontsize = 50,color = 'black')
ax.set_xticks(x)
ax.set_xticklabels(st_1920['Squad'],color = 'black',fontsize = 35)
ax.legend()
autolabel(b4)
autolabel(b5)"""
#plt.show()
# Out:
# "fig,ax = plt.subplots()\nfig.set_figheight(50)\nfig.set_figwidth(100)\nwidth = 0.35\nb4 = ax.bar([i - 0.5*width for i in x],gk_1920['GA90'],width,label = '19/20',color = 'yellow')\nb5 = ax.bar([i + 0.5*width for i in x],gk_2021['GA90'],width,label = '20/21',color = 'red',alpha = 0.5)\nax.set_ylabel('Goals conceded/90',fontsize = 50,color = 'black')\nax.set_title('Goals conceded/90 for all teams grouped by season',fontsize = 50,color = 'black')\nax.set_xticks(x)\nax.set_xticklabels(st_1920['Squad'],color = 'black',fontsize = 35)\nax.legend()\nautolabel(b4)\nautolabel(b5)"

# %%
# Plot of Goals conceded/90 19/20 vs 20/21
fig = go.Figure()

fig.add_trace(go.Bar(
    name = '19/20',
    x = gk_1920['Squad'],
    y = gk_1920['GA90'],
    text = gk_1920['GA90'],
    textposition='outside',
    marker_color = 'indianred',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.add_trace(go.Bar(name = '20/21',x = gk_1920['Squad'],y = gk_2021['GA90'],text = gk_2021['GA90'],textposition='outside',marker_color = 'lightsalmon',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.update_layout(
    title='Goals conceded per 90 by all clubs grouped by season',
    title_font_size = 30,
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='GA/90',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1, 
    #uniformtext_minsize = 10, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
py.plot(fig,name = 'goal_conc')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="468e7c5d-11b2-4926-a133-c85ce2245d0c" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("468e7c5d-11b2-4926-a133-c85ce2245d0c")) {
#                     Plotly.newPlot(
#                         '468e7c5d-11b2-4926-a133-c85ce2245d0c',
# ...

# %%
"""
In terms of goal concession, West Brom, Leeds United and Crystal Palace are at the forefront with over 1.8 goals conceded per 90. Crystal 
Palace find their number high courtesy of the 7-0 drubbing at Selhurst but also due to their terrible run of form and high goal concession. 

From the Big Six Manchester United are at the front with almost 1.5 goals conceded/90, and even though the stat is high due to the 6-1 loss
at Old Trafford, it is a fair assumption considering their terrible home record and tendency to fall behind by 2 and mount a comeback 
in away games. 

Manchester City had the second lowest goal concession/90 last season and this season so far have had the best defensive record and indeed
the lowest goal concession tally at 0.87, followed by Jose's Tottenham Hotspurs at 0.94, who have put their title credentials firmly in sight with
a strong start to the season.

"""
# Out:
# "\nIn terms of goal concession, West Brom, Leeds United and Crystal Palace are at the forefront with over 1.8 goals conceded per 90. Crystal \nPalace find their number high courtesy of the 7-0 drubbing at Selhurst but also due to their terrible run of form and high goal concession. \n\nFrom the Big Six Manchester United are at the front with almost 1.5 goals conceded/90, and even though the stat is high due to the 6-1 loss\nat Old Trafford, it is a fair assumption considering their terrible home record and tendency to fall behind by 2 and mount a comeback \nin away games. \n\nManchester City had the second lowest goal concession/90 last season and this season so far have had the best defensive record and indeed\nthe lowest goal concession tally at 0.87, followed by Jose's Tottenham Hotspurs at 0.94, who have put their title credentials firmly in sight with\na strong start to the season.\n\n"

# %%
# Horizontal Chart of the Difference in Goals Conceded/90 : 20/21 - 19/20

diff_ga = pd.DataFrame()
diff_ga['Squads'] = np.array(st_2021['Squad'])
diff_ga['Difference'] = np.array(gk_1920['GA90'] - gk_2021['GA90'])
diff_ga['Positive'] = diff_ga['Difference']>0

fig = go.Figure()
fig.add_trace(go.Bar(
    name = '19/20',
    x = diff_ga['Difference'],
    y = diff_ga['Squads'],
    text = [round(i,2) for i in diff_ga['Difference']],
    textposition='outside',
    marker_color = diff_ga.Positive.map({True:'limegreen',False:'tomato'}),
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    #width = 0.35,
    orientation = 'h'))
fig.update_layout(
    title='Difference between Goals Conceded/90 of both seasons',
    title_font_size = 30,
    yaxis_tickfont_size=16,
    xaxis=dict(
        title='Diff Goals/90',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=1.0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
py.plot(fig,name = 'diffgc')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e47fed03-1351-417e-9f9f-879b53d0bb00" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e47fed03-1351-417e-9f9f-879b53d0bb00")) {
#                     Plotly.newPlot(
#                         'e47fed03-1351-417e-9f9f-879b53d0bb00',
# ...

# %%
"""
Clearly the pandemic games have been more lax on defence as we see that a majority of the teams 
have conceded more goals/90 this season than the previous. However, Aston Villa have once again 
improved the most out of any team, with an astounding 0.69 less goals conceded this season. 

If even that statistic is not enough to put doubt away regarding Aston Villa's resurgence, their
clean sheet percentage is a whopping 53.7%, currently standing as the best clean sheet percentage
in the league, followed by Manchester City at 46.7%. It is worth keeping in mind that they have 
yet to face Liverpool, Tottenham and Manchester City, three fixtures that could cement their rise
or deem their ascension to be a mere purple patch. 

West Brom and Leeds have the highest difference due in part to their step up from the Championship
where they had the least goals conceded to the Premier League where they have the worst. 

Sheffield United have the highest increase from last season, a torrid winless run that has seen them 
cemented to the bottom of the table, and Chris Wilder's men are in serious trouble of being out of 
the Premier League before the halftime mark. 

Of the Big Six, Manchester United and Liverpool have both come off worse owing to their heavy defeats
whereas the rest of the lot have improved (yes even Arsenal). However their changes are not extraordinary
owing to an already good defence. Chelsea have benefitted from the addition of Mendy and Silva, conceding
0.18 less goals/90, and a 10% increase on clean sheet percentage. 

Southampton and West Ham United are the biggest improvers after Aston Villa following not so ideal 19/20 seasons.
West Ham in particular, who had to wait for the final matchday last season to ensure safety, have come out of the 
blocks with a fierce drive, defeating Wolves, Leicester and Everton while drawing to Tottenham (THAT Manuel Lanzini goal)
and Manchester City.  
"""
# Out:
# "\nClearly the pandemic games have been more lax on defence as we see that a majority of the teams \nhave conceded more goals/90 this season than the previous. However, Aston Villa have once again \nimproved the most out of any team, with an astounding 0.69 less goals conceded this season. \n\nIf even that statistic is not enough to put doubt away regarding Aston Villa's resurgence, their\nclean sheet percentage is a whopping 53.7%, currently standing as the best clean sheet percentage\nin the league, followed by Manchester City at 46.7%. It is worth keeping in mind that they have \nyet to face Liverpool, Tottenham and Manchester City, three fixtures that could cement their rise\nor deem their ascension to be a mere purple patch. \n\nWest Brom and Leeds have the highest difference due in part to their step up from the Championship\nwhere they had the least goals conceded to the Premier League where they have the worst. \n\nSheffield United have the highest increase from last season, 
# ...

# %%
# Clean Sheet Percentage Plot
fig = go.Figure()

fig.add_trace(go.Bar(
    name = '19/20',
    x = gk_1920['Squad'],
    y = gk_1920['CS%'],
    text = gk_1920['CS%'],
    textposition='outside',
    textfont_size = 14,
    marker_color = 'rgb(55, 83, 109)',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.add_trace(go.Bar(
    name = '20/21',
    x = gk_1920['Squad'],
    y = gk_2021['CS%'],
    text = gk_2021['CS%'],
    textposition='outside',
    textfont_size = 14,
    marker_color = ' rgb(26,118,255)',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.update_layout(
    title='Clean Sheet Percentage of All clubs grouped by season',
    title_font_size = 28,
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Clean Sheet Percentage',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group', 
    #uniformtext_minsize = 10,
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
)
"""
fig.update_layout(
    
    xaxis_tickangle=-30,
    #xaxis_title="Clubs",
    yaxis_title="Clean Sheet Percentage",
    font=dict(
        family="Courier New, monospace",
        size=15,
        color="Black"
    ),
    title = 'Clean Sheet Percentage of all times grouped by season',
    width = 2000,
    height = 1000,
    )#paper_bgcolor="LightSteelBlue",
    margin=dict(l=0, r=0, t=50, b=0))
"""
fig.show()
py.plot(fig,filename = 'Clean Sheet Perc')#,auto_open = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="239a8db4-7b39-4478-9bfa-95425b093df9" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("239a8db4-7b39-4478-9bfa-95425b093df9")) {
#                     Plotly.newPlot(
#                         '239a8db4-7b39-4478-9bfa-95425b093df9',
# ...

# %%
"""
Aston Villa, Manchester City and Southampton are the best performers in regards to clean sheets this season.
Liverpool have clearly paid the price of losing their defenders to injuries and have dropped to a 31.6% after a respectable
39.5 last season. 

Burnley are at a surprising 38%, but since they neither score goals nor concede them, giving us all three 0-0 draws of this
season, they remain in a relegation battle at the moment, clear of the pack but only just. 

Crystal Palace and West Brom have the one of the worst clean sheet percentages, complimenting our observation from the goals conceded
graph. Despite their terrible defensive record, for the moment Wilifried Zaha's contribution of 8 goals keeps them clear
of the bottom. 

Along with picking up their first win of the season against Newcastle, they also picked up a clean sheet taking their percentage to a baffling 5.3%,
which given how poorly they have started the season almost feels like too much.   
"""
# Out:
# "\nAston Villa, Manchester City and Southampton are the best performers in regards to clean sheets this season.\nLiverpool have clearly paid the price of losing their defenders to injuries and have dropped to a 31.6% after a respectable\n39.5 last season. \n\nBurnley are at a surprising 38%, but since they neither score goals nor concede them, giving us all three 0-0 draws of this\nseason, they remain in a relegation battle at the moment, clear of the pack but only just. \n\nCrystal Palace and West Brom have the one of the worst clean sheet percentages, complimenting our observation from the goals conceded\ngraph. Despite their terrible defensive record, for the moment Wilifried Zaha's contribution of 8 goals keeps them clear\nof the bottom. \n\nAlong with picking up their first win of the season against Newcastle, they also picked up a clean sheet taking their percentage to a baffling 5.3%,\nwhich given how poorly they have started the season almost feels like too much.   \n"

# %%
# Key Passes Plot

sc_1920 = pd.read_csv('19-20 Passing.csv')
sc_2021 = pd.read_csv('20-21 Passing.csv')
sc_1920['KP/90'] = [round(x,2) for x in sc_1920['KP']/sc_1920['90s']]
sc_1920 = sc_1920.drop([2,13,17])
sc_2021 = sc_2021.drop([7,8,17])
sc_2021['KP/90'] = [round(x,2) for x in sc_2021['KP']/sc_2021['90s']]
sc_2021

fig = go.Figure()

fig.add_trace(go.Bar(
    name = '19/20',
    x = sc_1920['Squad'],
    y = sc_1920['KP/90'],
    text = sc_1920['KP/90'],
    textposition='outside',
    marker_color = 'rgb(55, 83, 109)',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.add_trace(go.Bar(
    name = '20/21',
    x = sc_1920['Squad'],
    y = sc_2021['KP/90'],
    text = sc_2021['KP/90'],
    textposition='outside',
    marker_color = ' rgb(26,118,255)',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.update_layout(
    title='Key Passes per game grouped by season',
    title_font_size = 28,
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Key Passes/90',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e0c22b27-93af-43df-b872-3d76fa7edec8" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e0c22b27-93af-43df-b872-3d76fa7edec8")) {
#                     Plotly.newPlot(
#                         'e0c22b27-93af-43df-b872-3d76fa7edec8',
# ...

# %%
# Shot Creating Actions/90 Plot

sca_1920 = pd.read_csv('19-20 Shot Creation.csv')
sca_2021 = pd.read_csv('20-21 Shot Creation.csv')
#sca_1920['KP/90'] = [round(x,2) for x in sca_1920['KP']/sca_1920['90s']]
sca_1920 = sca_1920.drop([18,19,17])
#sca_2021 = sca_2021.drop([7,8,17])
#sca_2021['KP/90'] = [round(x,2) for x in sca_2021['KP']/sca_2021['90s']]
print(sca_2021)
print(sca_1920)

fig = go.Figure()

fig.add_trace(go.Bar(
    name = '19/20',
    x = sca_1920['Squad'],
    y = sca_1920['SCA90'],
    text = sca_1920['SCA90'],
    textposition='outside',
    marker_color = 'indianred',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.add_trace(go.Bar(
    name = '20/21',
    x = sca_1920['Squad'],
    y = sca_2021['SCA90'],
    text = sca_2021['SCA90'],
    textposition='outside',
    marker_color = 'lightsalmon',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.update_layout(
    title='Shot Creating Actions per game grouped by season',
    title_font_size = 28,
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Shot Creating Actions/90',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
)
# Out:
#               Squad  # Pl  90s  SCA  ...  GCA Sh  GCA Fld  GCA Def  GCA OG
# 0           Arsenal    25   19  317  ...       2        4        0       0
# 1          Brighton    25   19  359  ...       2        4        0       0
# 2           Burnley    21   17  236  ...       1        1        0       0
# 3           Chelsea    27   18  413  ...       4        4        0       0
# 4    Crystal Palace    21   19  290  ...       2        3        1       0
# 5           Everton    25   17  299  ...       6        3        0       0
# 6    Leicester City    24   18  335  ...       4        8        1       0
# 7         Liverpool    26   18  413  ...       6        3        1       0
# 8   Manchester City    23   17  436  ...       4        3        1       0
# 9    Manchester Utd    24   18  416  ...       5        5        3       0
# 10    Newcastle Utd    25   18  229  ...       1        5        0       0
# ...

# %%
pd.set_option('mode.chained_assignment', None)

# %%
"""fig,ax = plt.subplots()
fig.set_figheight(50)
fig.set_figwidth(100)
y = np.arange(len(pt_1920['Squad']))
width = 0.35
b8 = ax.bar([i - 0.5*width for i in y],pt_1920['Pts'],width,label = '19/20',color = 'orange')
b9 = ax.bar([i + 0.5*width for i in y],pt_2021['Pts'],width,label = '20/21',color = 'pink')
ax.set_ylabel('Points Obtained',fontsize = 50,color = 'black')
ax.set_title('Points of all teams by Matchweek 17 19/20 vs 20/21',fontsize = 50,color = 'k')
ax.set_xticks(y)
ax.set_xticklabels(pt_1920['Squad'],color = 'black',fontsize = 35)
ax.legend()
autolabel(b8)
autolabel(b9)
plt.show()"""
# Out:
# "fig,ax = plt.subplots()\nfig.set_figheight(50)\nfig.set_figwidth(100)\ny = np.arange(len(pt_1920['Squad']))\nwidth = 0.35\nb8 = ax.bar([i - 0.5*width for i in y],pt_1920['Pts'],width,label = '19/20',color = 'orange')\nb9 = ax.bar([i + 0.5*width for i in y],pt_2021['Pts'],width,label = '20/21',color = 'pink')\nax.set_ylabel('Points Obtained',fontsize = 50,color = 'black')\nax.set_title('Points of all teams by Matchweek 17 19/20 vs 20/21',fontsize = 50,color = 'k')\nax.set_xticks(y)\nax.set_xticklabels(pt_1920['Squad'],color = 'black',fontsize = 35)\nax.legend()\nautolabel(b8)\nautolabel(b9)\nplt.show()"

# %%
# Points by Matchweek 19 Plot
fig = go.Figure()
from plotly.io import write_image
fig.add_trace(go.Bar(
    name = '19/20',
    x = pt_1920['Squad'],
    y = pt_1920['Pts'],
    text = pt_1920['Pts'],
    textposition='outside',
    marker_color = 'rgb(55, 83, 109)',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.add_trace(go.Bar(name = '20/21',x = pt_1920['Squad'],y = pt_2021['Pts'],text = pt_2021['Pts'],marker_color = 'rgb(26,118,255)',
    textposition='outside',
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    width = 0.35))
fig.update_layout(title='Points by Matchweek 19 of both seasons',
                  title_font_size = 28,
    xaxis_tickfont_size=14,
    xaxis_tickangle = 30,
    yaxis=dict(
        title='Points',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    #bargroupgap=0.005, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    )
fig.show()
py.plot(fig,name = 'Points by MW 19')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="86ce041e-eb62-47e2-8e83-64ea20c1baba" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86ce041e-eb62-47e2-8e83-64ea20c1baba")) {
#                     Plotly.newPlot(
#                         '86ce041e-eb62-47e2-8e83-64ea20c1baba',
# ...

# %%
# Horizontal chart depicting difference in points at the same point last season
diff_g = pd.DataFrame()
diff_g['Squads'] = np.array(pt_2021['Squad'])
diff_g['Difference'] = np.array(pt_2021['Pts'] - pt_1920['Pts'])
diff_g['Positive'] = diff_g['Difference']>0
fig = go.Figure()

fig.add_trace(go.Bar(
    name = '19/20',
    x = diff_g['Difference'],
    y = diff_g['Squads'],
    text = [round(i,2) for i in diff_g['Difference']],
    textposition='outside',
    marker_color = diff_g.Positive.map({True:'limegreen',False:'tomato'}),
    marker_line_color="black",
    marker_line_width=2,
    opacity=0.8,
    #width = 0.35,
    orientation = 'h'))
fig.update_layout(
    title='Difference between Points obtained by MW19 of both seasons',
    title_font_size = 30,
    yaxis_tickfont_size=16,
    xaxis=dict(
        title='Diff Points',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=1.0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1, # gap between bars of the same location coordinate.
    #width = 2000,
    height = 1000,
    #paper_bgcolor="LightSteelBlue",
    #margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
py.plot(fig,filename = 'PtsDiff')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4a7b20ef-f3cc-4af7-9e02-84c8b5e65a95" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a7b20ef-f3cc-4af7-9e02-84c8b5e65a95")) {
#                     Plotly.newPlot(
#                         '4a7b20ef-f3cc-4af7-9e02-84c8b5e65a95',
# ...

# %%
"""
In keeping with the anomolous season we've had so far, we see that only Manchester City and indeed Leicester City show any signs of consistency.
It is clear to see that Sheffield United's 12th man so to speak has been invariably missed, the mixture of the absence of fans and second season syndrome seeming to be the reason behind their alarming fall in form. 

With points being the most important statistic to sum up our findings, we come to the closing section detailing the winners and losers of the impact of Covid-19 on Premier League football. 

Winners : 
1) Aston Villa : 
Aston Villa have clearly shown a hunger and an eagerness to prove that the fortuituous occurences of last season (The Goal line goal against Southampton) that saved them from the drop are not to be wasted, and have grabbed the new season by the horns. Their meteoric improvement in both Offense and Defense stands out in every single visualization that exists to be analyzed, and are quite clearly the biggest winners of the pandemic season. 

2) Southampton : 
Southampton were quite clearly a team struggling to put together anything of note or of value last season. Danny Ings at times seemed to singlehandedly  carry them through matches by scrounging points via his crucial goals, but alarm bells started ringing when Leicester thrashed the Saints by 9 goals to  nil. The words fraud and sacked in the morning echoed around Ralph Hassenhutl. But in a situation where the less economically gifted clubs of the Premier League have struggled, Southampton have, at least in the competition, turned over a new leaf. Improved defensive records, more goals scored, more chances created, the Saints have all the hallmarks of a side that show no signs of halting their improvement. 

Unlike a few of the clubs on this list that improved after the start of the new season, Southampton seemed to start their upsurge after their own demolition against Leicester, and make no mistake about it, deserve their place in the table and indeed on this list. 

3) Manchester United : 
More of credit to the arrival of Bruno Fernandes than the utilization of the pandemic season, you only need to look at Fernandes' numbers to 
remark on how much of an effect his arrival from Sporting has had on a team that survived on false dawns that led to horrible performances. 
Indeed, closer evaluation shows that their defensive records and their Clean sheet records have not improved, but the number of chances, shots,
goals and most importantly points obtained while compared to last season give credence to a side that have been galvanised by a new transfer and 
no matter what the situation are always in the game, and can flick the switch at any given time. 

4) West Ham United : 
When Michael Antonio scored his penalty against United to ensure a draw on Matchweek 37 last season, the relief on the face of West Ham fans 
did not belie the thought that had crossed everyone's minds, why were they there in the first place? Poor performances, missed chances and a 
heavy reliance on Michael Antonio meant a fairly frantic end to a season to forget. Many had in fact deemed them to be involved in the relegation
battle of this season as well. That theory was quickly put to dust. 

Unlike Man United, West Ham's performance boost comes from a hugely impressive defensive showing, with their clean sheets record being the 3rd best
in the league so far, and indeed the 6th fewest goals conceded. As things stand West Ham sit comfortably in the top half of the table, and can easily
mount a push for the European places. 

Losers : 
1) Sheffield United : 
One of the biggest wonders of the season is where did it all go wrong for the Blades? A brilliant push to the European places, impressive and united
displays, where in a world of individual brilliance here were a team with such coordination and spirit of togetherness. But anyone who watched the end 
of the previous season would not be too surprised by their fall, in fact the only surprising aspect of it is the nature of their sudden and meteoric fall.

Only 10 goals in 19 matches this season to a 23 last season sums up their torrid start. Sheffield were never a goalscoring outfit but an almost aversion to
goals really is a damning indictment of their performances. Their most disappointing drop, however, has been at the back. On an average Sheffield have conceded 
1.68 goals per each 90 minutes of football this season, which along with their measly goalscoring makes it nigh on impossible for any sort of points.

2) Liverpool : 
Now, before I'm told how Liverpool's team is the best to ever do it after being told whichever team I support is worse than them (to be honest they are), hear 
me out and let me paint you a picture. It's the end of the 19/20 season and indeed the end of Liverpool's 30 year long wait for the Premier league trophy. But 
behind the raucous celebration, there was a feeling that Manchester City, whose normally stonewall defence had collapsed in the wake of Laporte's injury, would be
back to challenge for the trophy. Yet only a fair few asked the pertinent question. What would happen if Liverpool ran into that problem? Surely a team that was 
one of the best in the world, needed some best in the world bench players to support their title defence? Understandably however, the pandemic denied Liverpool the 
funds to acquire those players. Koulibali, Upamecano, Jules Kunde, Sven Botman were all linked with Liverpool, none purchased. And in cruel irony, their defence 
suffered numerous injuries, requiring midfielders to deputise in those positions, weakening their attack and the title holders produced performances that were all 
blunter than the ones before, leakier than before. No longer were they the dogged pressing force, or the relentless attackers, even the Fortress of Anfield fell to 
a limp display against Burnley.

Through no fault of their own, except for a lack of recruitment denied by the pandemic, Liverpool find themselves in a position where the cities of Manchester and
Leicester are clear of them and look to be in pole position to lead the title charge. 
"""
# Out:
# "\nIn keeping with the anomolous season we've had so far, we see that only Manchester City and indeed Leicester City show any signs of consistency.\nIt is clear to see that Sheffield United's 12th man so to speak has been invariably missed, the mixture of the absence of fans and second season syndrome seeming to be the reason behind their alarming fall in form. \n\nWith points being the most important statistic to sum up our findings, we come to the closing section detailing the winners and losers of the impact of Covid-19 on Premier League football. \n\nWinners : \n1) Aston Villa : \nAston Villa have clearly shown a hunger and an eagerness to prove that the fortuituous occurences of last season (The Goal line goal against Southampton) that saved them from the drop are not to be wasted, and have grabbed the new season by the horns. Their meteoric improvement in both Offense and Defense stands out in every single visualization that exists to be analyzed, and are quite clearly the bigg
# ...

# %%
pt_1920
# Out:
#     Pos            Squad  MP   W  L   D  GD  Pts  GF  GA
# 0   11           Arsenal  19   5  9   5  -3   24  25  28
# 1   18     Aston Villa    19   5  3  11  -8   18  25  33
# 2   15          Brighton  19   5  5   9  -6   20  22  28
# 3   12           Burnley  19   7  3   9  -7   24  23  30
# 4    4           Chelsea  19  10  2   7   6   32  33  27
# 5    9    Crystal Palace  19   7  5   7  -4   26  17  21
# 6   13           Everton  19   6  4   9  -8   22  21  29
# 7    2         Leicester  19  12  3   4  23   39  41  18
# 8    1         Liverpool  19  18  1   0  34   55  48  14
# 9    3          Man City  19  12  2   5  29   38  52  23
# 10   8           Man Utd  19   7  7   5   7   28  30  23
# 11  10         Newcastle  19   7  4   8  -9   25  19  28
# 12   7   Sheffield Utd    19   7  8   4   6   29  23  17
# 13  14       Southampton  19   6  3  10 -14   21  23  37
# 14   6         Tottenham  19   8  5   6   7   29  34  27
# ...

# %%
pt_2021
# Out:
#     Pos           Squad  MP   W  D   L  GD  Pts  GF  GA
# 0    10         Arsenal  19   8  3   8   4   27  23  19
# 1    11     Aston Villa  16   8  2   6  11   26  29  18
# 2    17        Brighton  19   3  8   8  -7   17  22  29
# 3    16         Burnley  18   5  4   9 -12   19  10  22
# 4     8         Chelsea  19   8  5   6  10   29  33  23
# 5    13  Crystal Palace  19   6  5   8 -11   23  22  33
# 6     6         Everton  17  10  2   5   7   32  28  21
# 7     3       Leicester  19  12  2   5  14   38  35  21
# 8     4       Liverpool  19   9  7   3  15   34  37  22
# 9     2        Man City  18  11  5   2  18   38  31  13
# 10    1         Man Utd  19  12  4   3  11   40  36  25
# 11   15       Newcastle  18   5  4   9 -12   19  18  30
# 12   20   Sheffield Utd  19   1  2  16 -22    5  10  32
# 13    9     Southampton  18   8  5   5   5   29  26  21
# 14    5       Tottenham  18   9  6   3  16   33  33  17
# 15    7        West Ham  19   9  5   5   5   32  27  22
# ...

# %%
pt_2021.sort_values('Pos')
# Out:
#     Pos           Squad  MP   W  D   L  GD  Pts  GF  GA
# 10    1         Man Utd  19  12  4   3  11   40  36  25
# 9     2        Man City  18  11  5   2  18   38  31  13
# 7     3       Leicester  19  12  2   5  14   38  35  21
# 8     4       Liverpool  19   9  7   3  15   34  37  22
# 14    5       Tottenham  18   9  6   3  16   33  33  17
# 6     6         Everton  17  10  2   5   7   32  28  21
# 15    7        West Ham  19   9  5   5   5   32  27  22
# 4     8         Chelsea  19   8  5   6  10   29  33  23
# 13    9     Southampton  18   8  5   5   5   29  26  21
# 0    10         Arsenal  19   8  3   8   4   27  23  19
# 1    11     Aston Villa  16   8  2   6  11   26  29  18
# 5    13  Crystal Palace  19   6  5   8 -11   23  22  33
# 16   14          Wolves  19   6  4   9  -8   22  21  29
# 11   15       Newcastle  18   5  4   9 -12   19  18  30
# 3    16         Burnley  18   5  4   9 -12   19  10  22
# 2    17        Brighton  19   3  8   8  -7   17  22  29
# ...

# %%
b6_gk_2021 = gk_2021.iloc[[0,4,10,11,12,16]][:]
b6_gk_2021 = b6_gk_2021.drop(['# Pl','MP','Starts'],axis = 1)
b6_gk_2021 = b6_gk_2021.rename({"PKatt":"Keeper_PKatt","PKA":"Keeper_PKA","PKsv":'Keeper_PKsv',"PKm":'Keeper_PKm'},axis = 'columns')
b6_gk_2021 = b6_gk_2021.reset_index(drop = True)
b6_gk_2021
# Out:
#        Squad    Min  GA  ...  Keeper_PKA  Keeper_PKsv  Keeper_PKm
# 0    Arsenal  1,710  19  ...           0            1           0
# 1    Chelsea  1,710  23  ...           2            0           0
# 2  Liverpool  1,710  22  ...           3            1           2
# 3   Man City  1,620  13  ...           4            0           0
# 4    Man Utd  1,710  25  ...           4            0           0
# 5  Tottenham  1,620  17  ...           4            0           0
#
# [6 rows x 16 columns]

# %%
b6_st_2021 = st_2021.iloc[[0,4,10,11,12,16]][:]
b6_st_2021 = b6_st_2021.drop(['# Pl','Age','MP','Starts','Min','90s'],axis = 1)
b6_st_2021 = b6_st_2021.reset_index(drop = True)
b6_st_2021
# Out:
#        Squad  Poss  Gls  Ast  PK  ...  xG.1  xA.1  xG+xA  npxG.1  npxG+xA
# 0    Arsenal  53.8   23   16   3  ...  1.34  0.88   2.22    1.22     2.10
# 1    Chelsea  60.1   32   24   3  ...  1.61  1.00   2.61    1.41     2.41
# 2  Liverpool  64.8   35   21   5  ...  1.95  1.24   3.19    1.76     2.99
# 3   Man City  63.9   31   21   3  ...  1.85  1.29   3.13    1.64     2.93
# 4    Man Utd  52.8   35   24   5  ...  1.62  1.07   2.69    1.38     2.46
# 5  Tottenham  48.7   33   28   3  ...  1.46  0.98   2.44    1.33     2.31
#
# [6 rows x 21 columns]

# %%
b6_pt_2021 = pt_2021.iloc[[0,4,8,9,10,14]][['Squad','Pos','Pts','GD','GF','GA']]
b6_pt_2021 = b6_pt_2021.reset_index(drop = True)
b6_pt_2021
# Out:
#        Squad  Pos  Pts  GD  GF  GA
# 0    Arsenal   10   27   4  23  19
# 1    Chelsea    8   29  10  33  23
# 2  Liverpool    4   34  15  37  22
# 3   Man City    2   38  18  31  13
# 4    Man Utd    1   40  11  36  25
# 5  Tottenham    5   33  16  33  17

# %%
b6_2021 = pd.concat([b6_gk_2021,b6_st_2021,b6_pt_2021],axis = 1)
b6_2021 = b6_2021.loc[:,~b6_2021.columns.duplicated()]
b6_2021
# Out:
#        Squad    Min  GA  GA90  SoTA  Saves  ...  npxG.1  npxG+xA  Pos  Pts  GD  GF
# 0    Arsenal  1,710  19  1.00    61     45  ...    1.22     2.10   10   27   4  23
# 1    Chelsea  1,710  23  1.21    58     37  ...    1.41     2.41    8   29  10  33
# 2  Liverpool  1,710  22  1.16    64     45  ...    1.76     2.99    4   34  15  37
# 3   Man City  1,620  13  0.72    39     30  ...    1.64     2.93    2   38  18  31
# 4    Man Utd  1,710  25  1.32    66     46  ...    1.38     2.46    1   40  11  36
# 5  Tottenham  1,620  17  0.94    71     60  ...    1.33     2.31    5   33  16  33
#
# [6 rows x 40 columns]

# %%
b6_gk_1920 = gk_1920.iloc[[0,4,10,11,12,16]][:]
b6_gk_1920 = b6_gk_1920.drop(['# Pl','MP','Starts','GA'],axis = 1)
b6_gk_1920 = b6_gk_1920.rename({"PKatt":"Keeper_PKatt","PKA":"Keeper_PKA","PKsv":'Keeper_PKsv',"PKm":'Keeper_PKm'},axis = 'columns')
b6_gk_1920 = b6_gk_1920.reset_index(drop = True)
b6_st_1920 = st_1920.iloc[[0,4,10,11,12,16]][:]
b6_st_1920
b6_st_1920 = b6_st_1920.drop(['# Pl','Age','MP','Starts','Min'],axis = 1)
b6_st_1920 = b6_st_1920.reset_index(drop = True)
b6_pt_1920 = pt_1920.iloc[[0,4,8,9,10,14]][['Squad','Pos','Pts','GD','GF','GA']]
b6_pt_1920 = b6_pt_1920.reset_index(drop = True)
b6_1920 = pd.concat([b6_gk_1920,b6_st_1920,b6_pt_1920],axis = 1)
b6_1920 = b6_1920.loc[:,~b6_1920.columns.duplicated()]
b6_1920
# Out:
#        Squad    Min  GA90  SoTA  Saves  Save%  ...  npxG+xA  Pos  Pts  GD  GF  GA
# 0    Arsenal  3,420  1.26   189    143  0.783  ...     2.02  11    24  -3  25  28
# 1    Chelsea  3,420  1.42   115     65  0.548  ...     2.84   4    32   6  33  27
# 2  Liverpool  3,418  0.87   107     75  0.701  ...     3.15   1    55  34  48  14
# 3   Man City  3,418  0.92   107     73  0.701  ...     3.97   3    38  29  52  23
# 4    Man Utd  3,420  0.95   125     92  0.736  ...     2.26   8    28   7  30  23
# 5  Tottenham  3,420  1.24   172    130  0.756  ...     1.94   6    29   7  34  27
#
# [6 rows x 40 columns]

# %%
# Spider pLot of goals scored by matchweek 19 of big six teams
val = np.array(b6_2021.iloc[0][['Gls','GA','Poss','CS%','Pts']]).astype(float)
categories = ['Goals Scored','Goals Conceded','Possession','Clean Sheet Percentage','Points by MW 17']
import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig = make_subplots(rows = 1,cols = 2,specs=[[{'type': 'polar'}]*2],subplot_titles=['19/20','20/21'])

fig.add_trace(go.Barpolar(r=  np.array(b6_1920.iloc[:]['GF']).astype(float),
                              theta = b6_2021['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8

),row = 1,col = 1)
fig.add_trace(go.Barpolar(r=  np.array(b6_2021.iloc[:]['GF']).astype(float),
                              theta = b6_2021['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8
                            
),row = 1,col = 2)
  
fig.update_layout(
    title = 'Goals Scored till Matchweek 19 by Big Six Teams 19/20 and 20/21',
  polar=dict(
      radialaxis=dict(range = [0,55],showticklabels = False,
      visible=True,
    )),
    polar2=dict(
        radialaxis=dict(range = [0,55],showticklabels = False,
      visible=True,
    )),
  showlegend=False,
    #paper_bgcolor="LightSteelBlue",
    margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4eac5b95-0779-4f70-915d-375aac472de7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4eac5b95-0779-4f70-915d-375aac472de7")) {
#                     Plotly.newPlot(
#                         '4eac5b95-0779-4f70-915d-375aac472de7',
# ...

# %%
# Spider pLot of goals conceded till MW 19 of the big six for both seasons
fig = go.Figure()
fig = make_subplots(rows = 1,cols = 2,specs=[[{'type': 'polar'}]*2],subplot_titles=['19/20','20/21'])

fig.add_trace(go.Barpolar(r=  np.array(b6_1920.iloc[:]['GA']).astype(float),
                              theta = b6_1920['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8

),row = 1,col = 1)
fig.add_trace(go.Barpolar(r=  np.array(b6_2021.iloc[:]['GA']).astype(float),
                              theta = b6_2021['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8
                            
),row = 1,col = 2)
  
fig.update_layout(
    title = 'Goals Conceded till Matchweek 19 by Big Six Teams 19/20 and 20/21',
  polar=dict(
      radialaxis=dict(range = [0,30],showticklabels = False,
      visible=True,
    )),
    polar2=dict(
        radialaxis=dict(range = [0,30],showticklabels = False,
      visible=True,
    )),
  showlegend=False,
    #paper_bgcolor="LightSteelBlue",
    margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="12fc05a4-1eaa-4d0b-972e-0f4a427fb268" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("12fc05a4-1eaa-4d0b-972e-0f4a427fb268")) {
#                     Plotly.newPlot(
#                         '12fc05a4-1eaa-4d0b-972e-0f4a427fb268',
# ...

# %%
# Spider pLot of Avergae Possession till MW 19 of the big six for both seasons
fig = go.Figure()
fig = make_subplots(rows = 1,cols = 2,specs=[[{'type': 'polar'}]*2],subplot_titles=['19/20','20/21'])

fig.add_trace(go.Barpolar(r=  np.array(b6_1920.iloc[:]['Poss']).astype(float),
                              theta = b6_1920['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8

),row = 1,col = 1)
fig.add_trace(go.Barpolar(r=  np.array(b6_2021.iloc[:]['Poss']).astype(float),
                              theta = b6_2021['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8
                            
),row = 1,col = 2)
  
fig.update_layout(
    title = 'Average Possession till Matchweek 19 by Big Six Teams 19/20 and 20/21',
  polar=dict(
      radialaxis=dict(range = [0,70],showticklabels = False,
      visible=True,
    )),
    polar2=dict(
        radialaxis=dict(range = [0,70],showticklabels = False,
      visible=True,
    )),
  showlegend=False,
    #paper_bgcolor="LightSteelBlue",
    margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d9680381-0691-4767-87a4-e8e344f12c37" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d9680381-0691-4767-87a4-e8e344f12c37")) {
#                     Plotly.newPlot(
#                         'd9680381-0691-4767-87a4-e8e344f12c37',
# ...

# %%
# Spider pLot of Clean Sheet Percentage till MW 19 of the big six for both seasons
fig = go.Figure()
fig = make_subplots(rows = 1,cols = 2,specs=[[{'type': 'polar'}]*2],subplot_titles=['19/20','20/21'])

fig.add_trace(go.Barpolar(r=  np.array(b6_1920.iloc[:]['CS%']).astype(float),
                              theta = b6_1920['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8

),row = 1,col = 1)
fig.add_trace(go.Barpolar(r=  np.array(b6_2021.iloc[:]['CS%']).astype(float),
                              theta = b6_2021['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8
                            
),row = 1,col = 2)
  
fig.update_layout(
    title = 'Clean Sheet Percentage till Matchweek 19 by Big Six Teams 19/20 and 20/21',
  polar=dict(
      radialaxis=dict(range = [0,60],showticklabels = False,
      visible=True,
    )),
    polar2=dict(
        radialaxis=dict(range = [0,60],showticklabels = False,
      visible=True,
    )),
  showlegend=False,
    #paper_bgcolor="LightSteelBlue",
    margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd16023f-7c09-4dbe-b789-e561ac459528" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd16023f-7c09-4dbe-b789-e561ac459528")) {
#                     Plotly.newPlot(
#                         'dd16023f-7c09-4dbe-b789-e561ac459528',
# ...

# %%
# Spider pLot of Points obtained till MW 19 of the big six for both seasons
fig = go.Figure()
fig = make_subplots(rows = 1,cols = 2,specs=[[{'type': 'polar'}]*2],subplot_titles=['19/20','20/21'])

fig.add_trace(go.Barpolar(r=  np.array(b6_1920.iloc[:]['Pts']).astype(float),
                              theta = b6_1920['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8

),row = 1,col = 1)
fig.add_trace(go.Barpolar(r=  np.array(b6_2021.iloc[:]['Pts']).astype(float),
                              theta = b6_2021['Squad'],
                            marker_color=["#FF2D00 ", '#0548FB', '#D7281C', '#05FBEC', '#0A0200','#FFFFFF'],
                            marker_line_color="black",
                            marker_line_width=2,
                            opacity=0.8
                            
),row = 1,col = 2)
  
fig.update_layout(
    title = 'Points obtained by Matchweek 19 by Big Six Teams 19/20 and 20/21',
  polar=dict(
      radialaxis=dict(range = [0,60],showticklabels = False,
      visible=True,
    )),
    polar2=dict(
        radialaxis=dict(range = [0,60],showticklabels = False,
      visible=True,
    )),
  showlegend=False,
    #paper_bgcolor="LightSteelBlue",
    margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e52ca04c-cc4d-48d6-80e5-4e41ba60ef33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e52ca04c-cc4d-48d6-80e5-4e41ba60ef33")) {
#                     Plotly.newPlot(
#                         'e52ca04c-cc4d-48d6-80e5-4e41ba60ef33',
# ...
